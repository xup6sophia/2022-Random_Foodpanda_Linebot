# %%
### 爬中央大學附近的 foodpanda 美食
### random_choose_restaurant 是random餐廳方法
import requests
import random

def random_choose_restaurant(restaurant_data):
    draw = random.choice(restaurant_data)
    print("抽到" + draw['name'])
    print("排名為" + str(draw['rating']))
    print( draw['redirection_url'])

    
url = 'https://disco.deliveryhero.io/listing/api/v1/pandora/vendors'
query = {
    'longitude': 121.1952988,  # 中央大學經度
    'latitude': 24.9681558,  # 中央大學緯度
    'language_id': 6,
    'include': 'characteristics',
    'dynamic_pricing': 0,
    'configuration': 'Variant1',
    'country': 'tw',
    'budgets': '',#低中高123
    'cuisine': '',
    'sort': 'rating_desc', #評分最高
    'food_characteristic': '',
    'use_free_delivery_label': False,
    'vertical': 'restaurants',
    'limit': 50,
    'offset': 0,
    'customer_type': 'regular'
}
headers = {
    'x-disco-client-id': 'web',
}
r = requests.get(url=url, params=query, headers=headers)


if r.status_code == requests.codes.ok:
    data = r.json()
    
    restaurants = data['data']['items']
   
    for restaurant in restaurants[:50]:
        print(restaurant['name'])
        print(restaurant['redirection_url'])
        print(restaurant['rating'])
        print('-----------------------------------------------------------------------------------')
    random_choose_restaurant(restaurants[:50])    
        
        
else:
    print('請求失敗')
# Out:
# 台越小吃
# https://foodpanda.com.tw/restaurant/dg1q/tai-yue-xiao-chi-dg1q
# 5.0
# -----------------------------------------------------------------------------------
# 旅人甜點 (桃園中壢店)
# https://foodpanda.com.tw/restaurant/zskw/lu-ren-tian-dian-tao-yuan-zhong-li-dian
# 5.0
# -----------------------------------------------------------------------------------
# 旅人甜點 (桃園福滿滿店)
# https://foodpanda.com.tw/restaurant/g7ip/lu-ren-tian-dian-tao-yuan-fu-man-man-dian
# 5.0
# -----------------------------------------------------------------------------------
# 春花紅豆餅 (中壢中平店)
# https://foodpanda.com.tw/restaurant/ruus/chun-hua-hong-dou-bing-zhong-li-zhong-ping-dian
# 5.0
# -----------------------------------------------------------------------------------
# 橙涼冰室CHILL ORANGE
# https://foodpanda.com.tw/restaurant/azn7/cheng-liang-bing-shi-chill-orange
# 5.0
# -----------------------------------------------------------------------------------
# 洪師傅便當
# https://foodpanda.com.tw/restaurant/co4z/hong-shi-fu-bian-dang
# 5.0
# -----------------------------------------------------------------------------------
# 紫月手作料理
# https://foodpanda.com.tw/restaurant/fzfo/zi-yue-shou-zuo-liao-li
# 5.0
# -----------------------------------------------------------------------------------
# 美斯樂 泰式打拋豬肉飯
# https://foodpanda.com.tw/restaurant/xyu3/mei-si-le-tai-shi-da-pao-zhu-rou-fan
# 5.0
# -----------------------------------------------------------------------------------
# 茗極Magic Tea
# https://foodpanda.com.tw/restaurant/jrpk/ming-ji-magic-tea
# 5.0
# -----------------------------------------------------------------------------------
# 茶聚 (中壢中正店)
# https://foodpanda.com.tw/restaurant/a8y6/cha-ju-zhong-li-zhong-zheng-dian
# 5.0
# -----------------------------------------------------------------------------------
# 薏難忘 (桃園中壢過嶺店)
# https://foodpanda.com.tw/restaurant/rd88/yi-nan-wang-tao-yuan-zhong-li-guo-ling-dian
# 5.0
# -----------------------------------------------------------------------------------
# 韓國叔叔 (平鎮文化店)
# https://foodpanda.com.tw/restaurant/zyll/han-guo-shu-shu-ping-zhen-wen-hua-dian
# 5.0
# -----------------------------------------------------------------------------------
# 茶棧 (中壢延平店)
# https://foodpanda.com.tw/restaurant/k4b5/cha-zhan-zhong-li-yan-ping-dian
# 4.9
# -----------------------------------------------------------------------------------
# 菓點子 (中壢過嶺店)
# https://foodpanda.com.tw/restaurant/zp6u/guo-dian-zi-zhong-li-guo-ling-dian
# 4.8
# -----------------------------------------------------------------------------------
# 艾瑞士健康餐飲
# https://foodpanda.com.tw/restaurant/o7jk/ai-rui-shi-jian-kang-can-yin
# 4.8
# -----------------------------------------------------------------------------------
# 喫茶小舖 (中壢民族店)
# https://foodpanda.com.tw/restaurant/fwto/chi-cha-xiao-pu-zhong-li-min-zu-dian
# 4.8
# -----------------------------------------------------------------------------------
# cama café (中壢九和店)
# https://foodpanda.com.tw/restaurant/e9nq/cama-cafe-zhong-li-jiu-he-dian
# 4.8
# -----------------------------------------------------------------------------------
# Tea's原味 (中壢中正店)
# https://foodpanda.com.tw/restaurant/lpia/teasyuan-wei-zhong-li-zhong-zheng-dian
# 4.8
# -----------------------------------------------------------------------------------
# 老窩咖啡館 (平鎮環南店)
# https://foodpanda.com.tw/restaurant/d3tk/lao-wo-ka-pei-guan-ping-zhen-huan-nan-dian
# 4.8
# -----------------------------------------------------------------------------------
# 草本茶 (中壢中美店)
# https://foodpanda.com.tw/restaurant/y9qo/cao-ben-cha-zhong-li-zhong-mei-dian
# 4.8
# -----------------------------------------------------------------------------------
# COMEBUY (中壢SOGO店)
# https://foodpanda.com.tw/restaurant/wfpq/comebuy-zhong-li-sogodian
# 4.8
# -----------------------------------------------------------------------------------
# 迷客夏 Milkshop (桃園元化店)
# https://foodpanda.com.tw/restaurant/e6ha/mi-ke-xia-milkshop-tao-yuan-yuan-hua-dian
# 4.8
# -----------------------------------------------------------------------------------
# STARBUCKS 星巴克 (平鎮民族門市)
# https://foodpanda.com.tw/restaurant/i0tr/starbucks-xing-ba-ke-ping-zhen-min-zu-men-shi
# 4.8
# -----------------------------------------------------------------------------------
# Abula阿不拉紅茶專賣店 (中壢民族店)
# https://foodpanda.com.tw/restaurant/bnlh/abulaa-bu-la-hong-cha-zhuan-mai-dian-zhong-li-min-zu-dian
# 4.8
# -----------------------------------------------------------------------------------
# 健康先生手作健身餐盒
# https://foodpanda.com.tw/restaurant/th30/jian-kang-xian-sheng-shou-zuo-jian-shen-can-he
# 4.8
# -----------------------------------------------------------------------------------
# 丸作食茶 (桃園中壢店)
# https://foodpanda.com.tw/restaurant/n9fh/wan-zuo-shi-cha-tao-yuan-zhong-li-dian
# 4.8
# -----------------------------------------------------------------------------------
# 拾午
# https://foodpanda.com.tw/restaurant/njfk/shi-wu-njfk
# 4.8
# -----------------------------------------------------------------------------------
# Mr.Wish 鮮果茶玩家 (中壢民族店)
# https://foodpanda.com.tw/restaurant/jrsi/mr-wish-xian-guo-cha-wan-jia-zhong-li-min-zu-dian
# 4.8
# -----------------------------------------------------------------------------------
# 李記紅茶冰 (中壢中山店)
# https://foodpanda.com.tw/restaurant/n1nc/li-ji-hong-cha-bing-zhong-li-zhong-shan-dian
# 4.8
# -----------------------------------------------------------------------------------
# 黛黛茶 (中壢民族店)
# https://foodpanda.com.tw/restaurant/yzek/dai-dai-cha-zhong-li-min-zu-dian
# 4.8
# -----------------------------------------------------------------------------------
# 搖搖再喝 (中壢新生店)
# https://foodpanda.com.tw/restaurant/pwoo/yao-yao-zai-he-zhong-li-xin-sheng-dian
# 4.8
# -----------------------------------------------------------------------------------
# 中壢夜市-台南小吃(簡)
# https://foodpanda.com.tw/restaurant/m945/zhong-li-ye-shi-tai-nan-xiao-chi-jian
# 4.8
# -----------------------------------------------------------------------------------
# 茶朵ㄦ (健行概念店)
# https://foodpanda.com.tw/restaurant/ec8c/cha-duo-er-jian-xing-gai-nian-dian
# 4.8
# -----------------------------------------------------------------------------------
# Häagen-Dazs 哈根達斯 (SOGO百貨中壢店)
# https://foodpanda.com.tw/restaurant/u2y3/haagen-dazs-ha-gen-da-si-sogobai-huo-zhong-li-dian
# 4.8
# -----------------------------------------------------------------------------------
# TRUEWIN初韻 水果_茶專賣 (中壢站前店)
# https://foodpanda.com.tw/restaurant/i0qk/truewinchu-yun-shui-guo-_cha-zhuan-mai-zhong-li-zhan-qian-dian
# 4.8
# -----------------------------------------------------------------------------------
# 五桐號Wootea (中壢SOGO店)
# https://foodpanda.com.tw/restaurant/ptb9/wu-tong-hao-wootea-zhong-li-sogodian
# 4.8
# -----------------------------------------------------------------------------------
# 可不可熟成紅茶 (平鎮文化店)
# https://foodpanda.com.tw/restaurant/b0i4/ke-bu-ke-shou-cheng-hong-cha-ping-zhen-wen-hua-dian
# 4.8
# -----------------------------------------------------------------------------------
# 大苑子 (中壢新明店)
# https://foodpanda.com.tw/restaurant/nwnk/da-yuan-zi-zhong-li-xin-ming-dian
# 4.8
# -----------------------------------------------------------------------------------
# 熊好茶 (中壢民族店)
# https://foodpanda.com.tw/restaurant/v492/xiong-hao-cha-zhong-li-min-zu-dian
# 4.8
# -----------------------------------------------------------------------------------
# 阿郎蒜味鹽酥雞 (中壢民族店)
# https://foodpanda.com.tw/restaurant/n6bz/a-lang-suan-wei-yan-su-ji-zhong-li-min-zu-dian
# 4.8
# -----------------------------------------------------------------------------------
# 七盞茶 (中壢光明店)
# https://foodpanda.com.tw/restaurant/m65m/qi-zhan-cha-zhong-li-guang-ming-dian
# 4.8
# -----------------------------------------------------------------------------------
# COMEBUY (中壢民族店)
# https://foodpanda.com.tw/restaurant/r3rx/comebuy-zhong-li-min-zu-dian
# 4.8
# -----------------------------------------------------------------------------------
# 鶴茶樓 (中壢中山店)
# https://foodpanda.com.tw/restaurant/gxlb/he-cha-lou-zhong-li-zhong-shan-dian
# 4.8
# -----------------------------------------------------------------------------------
# Bakso Formosa
# https://foodpanda.com.tw/restaurant/nzwv/bakso-formosa
# 4.8
# -----------------------------------------------------------------------------------
# 清心福全 (中壢民族店)
# https://foodpanda.com.tw/restaurant/c4kh/qing-xin-fu-quan-zhong-li-min-zu-dian
# 4.8
# -----------------------------------------------------------------------------------
# 素心麻辣臭豆腐(蔬食)
# https://foodpanda.com.tw/restaurant/gt7v/su-xin-ma-la-chou-dou-fu-shu-shi
# 4.8
# -----------------------------------------------------------------------------------
# 萬波島嶼紅茶 (平鎮環南店)
# https://foodpanda.com.tw/restaurant/yq3f/wan-bo-dao-yu-hong-cha-ping-zhen-huan-nan-dian
# 4.8
# -----------------------------------------------------------------------------------
# COLD STONE (SOGO百貨中壢店)
# https://foodpanda.com.tw/restaurant/q8iy/cold-stone-sogobai-huo-zhong-li-dian
# 4.8
# -----------------------------------------------------------------------------------
# 清心福全 (平鎮義民店)
# https://foodpanda.com.tw/restaurant/b5lg/qing-xin-fu-quan-ping-zhen-yi-min-dian
# 4.8
# -----------------------------------------------------------------------------------
# 清原芋圓 (中壢大同店)
# https://foodpanda.com.tw/restaurant/jz25/qing-yuan-yu-yuan-zhong-li-da-tong-dian
# 4.8
# -----------------------------------------------------------------------------------
# 抽到Mr.Wish 鮮果茶玩家 (中壢民族店)
# 排名為4.8
# https://foodpanda.com.tw/restaurant/jrsi/mr-wish-xian-guo-cha-wan-jia-zhong-li-min-zu-dian

# %%
###爬json
import requests


url = 'https://disco.deliveryhero.io/listing/api/v1/pandora/vendors'
query = {
    'longitude': 121.1952988,  # 經度
    'latitude': 24.9681558,  # 緯度
    'language_id': 6,
    'include': 'characteristics',
    'dynamic_pricing': 0,
    'configuration': 'Variant1',
    'country': 'tw',
    'budgets': '',#低中高123
    'cuisine': '',
    'sort': 'rating_desc', #評分最高
    'food_characteristic': '',
    'use_free_delivery_label': False,
    'vertical': 'restaurants',
    'limit': 50,
    'offset': 0,
    'customer_type': 'regular'
}
headers = {
    'x-disco-client-id': 'web',
}
r = requests.get(url=url, params=query, headers=headers)
if r.status_code == requests.codes.ok:
    data = r.json()
    print(data)
# Out:
# {'status_code': 200, 'message': 'success', 'data': {'available_count': 727, 'returned_count': 50, 'events': [], 'close_reasons': [], 'banner': '', 'items': [{'id': 143531, 'code': 'dg1q', 'accepts_instructions': True, 'address': '(△)桃園市平鎮區育達路107號', 'address_line2': '', 'budget': 1, 'chain': {'code': '', 'name': '', 'main_vendor_code': '', 'url_key': ''}, 'city': {'name': 'Taoyuan City'}, 'cuisines': [{'id': 252, 'name': '東南亞', 'url_key': 'dong-nan-ya', 'main': True}], 'custom_location_url': '', 'customer_type': 'all', 'delivery_box': '', 'delivery_fee_type': 'amount', 'description': '食品業者登錄字號：H-200217343-00000-6', 'distance': 2.4100622155496176, 'food_characteristics': [], 'has_delivery_provider': True, 'hero_image': 'https://images.deliveryhero.io/image/fd-tw/LH/dg1q-hero.jpg', 'hero_listing_image': 'https://images.deliveryhero.io/image/fd-tw/LH/dg1q-listing.jpg', 'is_new_until': '2022-04-11T00:00:00Z', 'premium_position': 0, 'latitude': 24.9515484, 'logo': '', 'longitude': 121.2106607, 'loyalty_percentage_amount': 0.0, 'loyalty_program_enabled': False, 'maximum_express_order_amount': 0, 'metadata': {'has_discount': False, 'timezone': 'Asia/Taipei', 'close_reasons': [], 'available_in': None, 'events': [], 'is_delivery_available': True, 'is_pickup_available': True, 'is_dine_in_available': False, 'is_express_delivery_available': False, 'is_temporary_closed': False, 'is_flood_feature_closed': False}, 'minimum_delivery_fee': 29.0, 'minimum_delivery_time': 20.0, 'minimum_order_amount': 79.0, 'minimum_pickup_time': 5.0, 'name': '台越小吃', 'payment_types': [], 'post_code': '324006', 'primary_cuisine_id': 252, 'rating': 5.0, 'redirection_url': 'https://foodpanda.com.tw/restaurant/dg1q/tai-yue-xiao-chi-dg1q', 'review_number': 9, 'review_with_comment_number': 0, 'score': 0.0, 'service_fee_percentage_amount': 0, 'service_tax_percentage_amount': 0, 'tag': '', 'tags': [], 'url_key': 'tai-yue-xiao-chi-dg1q', 'vat_percentage_amount': 0, 'characteristics': {'cuisines': [{'id': 252, 'name': '東南亞', 'url_key': 'dong-nan-ya', 'main': True}], 'food_characteristics': [], 'primary_cuisine': {'id': 252, 'name': '東南亞', 'url_key': 'dong-nan-ya', 'main': True}}, 'vendor_points': 13027, 'vertical': 'restaurants', 'vertical_segment': 'restaurants', 'vertical_parent': 'Restaurant', 'web_path': 'https://foodpanda.com.tw/restaurant/dg1q/tai-yue-xiao-chi-dg1q', 'website': '', 'has_online_payment': True, 'discounts_info': [], 'discounts': [], 'vendor_legal_information': {'legal_name': '無', 'trade_register_number': ''}, 'disclaimers': [], 'customer_phone': '+886930539518', 'vertical_type_ids': ['restaurants'], 'delivery_provider': 'platform_delivery', 'is_active': True, 'is_best_in_city': False, 'is_checkout_comment_enabled': False, 'is_delivery_enabled': True, 'is_new': False, 'is_pickup_enabled': True, 'is_premium': False, 'is_preorder_enabled': True, 'is_promoted': False, 'is_replacement_dish_enabled': False, 'is_service_fee_enabled': False, 'is_service_tax_enabled': False, 'is_service_tax_visible': False, 'is_test': False, 'is_vat_disabled': False, 'is_vat_included_in_product_price': True, 'is_vat_visible': False, 'is_voucher_enabled': True, 'tag_ids': []}, {'id': 145449, 'code': 'zskw', 'accepts_instructions': True, 'address': '(△)桃園市中壢區中平路41號', 'address_line2': '', 'budget': 1, 'chain': {'code': '', 'name': '', 'main_vendor_code': '', 'url_key': ''}, 'city': {'name': 'Taoyuan City'}, 'cuisines': [{'id': 176, 'name': '甜點', 'url_key': 'dessert', 'main': True}], 'custom_location_url': '', 'customer_type': 'all', 'delivery_box': '', 'delivery_fee_type': 'amount', 'description': '', 'distance': 3.345747271823655, 'food_characteristics': [{'id': 55, 'name': '<店內價>', 'is_halal': False, 'is_vegetarian': False}], 'has_delivery_provider': True, 'hero_image': 'https://images.deliveryhero.io/image/fd-tw/LH/zskw-hero.jpg', 'hero_listing_image': 'https://images.deliveryhero.io/image/fd-tw/LH/zskw-listing.jpg', 'is_new_until': '2022-05-01T00:00:00Z', 'premium_position': 0 ...
